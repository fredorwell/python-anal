# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
df = pd.read_csv('laptops_10.csv', encoding='latin-1')

# %%
# Out:
# Collecting seaborn
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#      -------------------------------------- 293.3/293.3 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\kolya\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (1.24.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\kolya\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (3.6.3)
# Requirement already satisfied: pandas>=0.25 in c:\users\kolya\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (2.0.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kolya\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\kolya\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\kolya\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kolya\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kolya\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\kolya\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\kolya\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\kolya\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (21.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kolya\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.25->seaborn) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\kolya\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\kolya\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.12.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches                         Cpu   Ram
# 0   Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 2.3GHz   8GB  \
# 1   Apple  Macbook Air  Ultrabook    13.3        Intel Core i5 1.8GHz   8GB
# 2      HP       250 G6   Notebook    15.6  Intel Core i5 7200U 2.5GHz   8GB
# 3   Apple  MacBook Pro  Ultrabook    15.4        Intel Core i7 2.7GHz  16GB
# 4   Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 3.1GHz   8GB
#
#                             Gpu  OpSys  Weight  Price_euros Cpu_Company
# 0  Intel Iris Plus Graphics 640  macOS    1.37      1339.69       Intel  \
# 1        Intel HD Graphics 6000  macOS    1.34       898.94       Intel
# 2         Intel HD Graphics 620  No OS    1.86       575.00       Intel
# 3            AMD Radeon Pro 455  macOS    1.83      2537.45       Intel
# 4  Intel Iris Plus Graphics 650  macOS    1.37      1803.60       Intel
#
#    Memory_Amount   Memory_Type
# 0            128           SSD
# 1            128  FlashStorage
# 2            256           SSD
# 3            512           SSD
# 4            256           SSD

# %% [markdown]
# 1.1 Изучите количество памяти с помощью matplotlib

# %%
plt.figure(figsize=(6, 4))
plt.hist(df['Memory_Amount'], bins=50)
plt.title('Размер памяти')
plt.xlabel('Объем памяти')
plt.ylabel('Кол-во ноутбуков')
# Out:
# Text(0, 0.5, 'Кол-во ноутбуков')

# %% [markdown]
# 1.2 Изучите стоимость ноутбуков с помощью matplotlib

# %%
plt.figure(figsize=(6, 4))
plt.hist(df['Price_euros'], bins=100)
plt.title('Размер памяти')
plt.xlabel('Объем памяти')
plt.ylabel('Кол-во ноутбуков')
# Out:
# Text(0, 0.5, 'Кол-во ноутбуков')

# %% [markdown]
# 1.3 Изучите вес ноутбуков с помощью matplotlib

# %%
plt.figure(figsize=(6, 4))
plt.hist(df['Weight'], bins=100)
plt.title('Размер памяти')
plt.xlabel('Объем памяти')
plt.ylabel('Кол-во ноутбуков')
# Out:
# Text(0, 0.5, 'Кол-во ноутбуков')

# %% [markdown]
# 2.1 Изучите распределение типов носителя
# 2.2 Изучите распределение компаний производителей
# 2.3 Изучите распределение операционной системы
# 2.4 Изучите распределение компаний производителей CPU
#
# Постройте график
# Сделайте выводы

# %%
plt.figure(figsize=(6, 4))

plt.pie(values, labels=names, autopct='%1.1f%%')
plt.title('Типы памяти')
# plt.legend(names)
# Out:
# Text(0.5, 1.0, 'Типы памяти')

# %%
memory = df["Memory_Type"].value_counts()
names = memory.index
values = memory.values
memory.head()
# Out:
# Memory_Type
# SSD             641
# HDD             576
# FlashStorage     74
# Hybrid           12
# Name: count, dtype: int64

# %%
print(names)
print(values)
# Out:
# Index(['SSD', 'HDD', 'FlashStorage', 'Hybrid'], dtype='object', name='Memory_Type')
# [641 576  74  12]

# %% [markdown]
# 2.2 Изучите распределение компаний производителей

# %%
plt.figure(figsize=(6, 4))
br = df["Company"].value_counts()
br_names = br.index
br_values = br.values
plt.pie(br_values, labels=br_names, autopct='%1.1f%%')
plt.title('Типы памяти')
# plt.legend(names)
# Out:
# Text(0.5, 1.0, 'Типы памяти')

# %%
plt.figure(figsize=(6, 4))
plt.xticks(rotation=45)
plt.hist(df['Company'], bins=30)
# Out:
# (array([ 21., 274.,   0., 103.,   0., 158., 297.,   0., 297.,   0.,   3.,
#          54.,   0.,   6.,   0.,  48.,   2.,   0.,   4.,   0.,   4.,   7.,
#           0.,   7.,   0.,   9.,   3.,   0.,   3.,   3.]),
#  array([ 0. ,  0.6,  1.2,  1.8,  2.4,  3. ,  3.6,  4.2,  4.8,  5.4,  6. ,
#          6.6,  7.2,  7.8,  8.4,  9. ,  9.6, 10.2, 10.8, 11.4, 12. , 12.6,
#         13.2, 13.8, 14.4, 15. , 15.6, 16.2, 16.8, 17.4, 18. ]),
#  <BarContainer object of 30 artists>)

# %% [markdown]
# 2.3 Изучите распределение операционной системы

# %%
expl = [0.2, 0.03, 0.54, 0.05, 0.07, 0.06, 0.05, 0.04, 0.5]
plt.figure(figsize=(10, 8))
op_s = df["OpSys"].value_counts()
op_s_names = op_s.index
op_s_values = op_s.values
plt.pie(op_s_values, labels=op_s_names, autopct='%1.1f%%', explode=expl )
plt.title('Типы операт. систем')
# plt.legend(names)
# Out:
# Text(0.5, 1.0, 'Типы операт. систем')

# %%
plt.figure(figsize=(6, 4))
plt.xticks(rotation=45)
plt.hist(df['OpSys']);

# %% [markdown]
# 2.4 Изучите распределение компаний производителей CPU

# %%
list_c = ['#4fb1db','#db3540','#35db77']
plt.figure(figsize=(6, 6))
cpu = df["Cpu_Company"].value_counts()
cpu_names = cpu.index
cpu_values = cpu.values
plt.pie(cpu_values, labels=cpu_names, autopct='%1.1f%%', colors=list_c)
plt.title('Производители процессоров')
# plt.legend(names)
# Out:
# Text(0.5, 1.0, 'Производители процессоров')

# %% [markdown]
# Изучите взаимосвязь компаний производителей ноутбуков и компаний производителей процессоров, используя сложенную или многорядовую столбчатую диаграмму
# Процессоры от Samsung не изучайте

# %% [markdown]
# 3.1 Постройте график в абсолютных величинах

# %%
df_3 = pd.crosstab(index=df['Company'], columns=df['Cpu_Company'])
df_3.drop('Samsung', inplace=True, axis=1)
df_3 = df_3.reset_index()

# %%
# Строим столбчатую многорядную диаграмму

plt.figure(figsize=(8, 6))

# определяем кол-во делений
n_ticks = np.arange(len(df_3['Intel']))

# определяем сдвиг
offset = 0.2

# определяем ширину столбцов
w = 0.4

# добавляем сдвиг к кол-ву делений
plt.bar(n_ticks - offset, df_3['Intel'], width=w)
plt.bar(n_ticks + offset, df_3['AMD'], width=w)

plt.title('Взаимосвязь компаний производителей ноутбуков и компаний производителей процессоров')
plt.xlabel('Производители ноутбуков')
plt.ylabel('Кол-во')
plt.legend(['Intel', 'AMD'])
plt.xticks(n_ticks, df_3['Company'], rotation = 30);  # добавляем метки делений

# %% [markdown]
# 3.2 Постройте график в относительных величинах

# %%
df_3_n = pd.crosstab(index=df['Company'], columns=df['Cpu_Company'], normalize='index')
df_3_n.drop('Samsung', inplace=True, axis=1)
df_3_n = df_3_n.reset_index()
df_3_n.head()
# Out:
# Cpu_Company Company       AMD     Intel
# 0              Acer  0.097087  0.902913
# 1             Apple  0.000000  1.000000
# 2              Asus  0.069620  0.930380
# 3             Chuwi  0.000000  1.000000
# 4              Dell  0.000000  1.000000

# %%
plt.figure(figsize=(8, 6))
plt.bar(df_3_n['Company'],df_3_n['AMD'])
plt.bar(df_3_n['Company'],df_3_n['Intel'], bottom=df_3_n['AMD'])
plt.legend(['AMD', 'Intel'])
plt.xticks(rotation = 45);

# %% [markdown]
# 4.1 Изучите взаимосвязь стоимости ноутбука и компании производителя процессора
#
# 4.2 Изучите взаимосвязь стоимости ноутбука и типа носителя памяти
#
# 4.3 Изучите взаимосвязь стоимости ноутбука и кол-ва оперативной памяти
#
# 4.4 Изучите взаимосвязь стоимости ноутбука и компании производителя
#
# Постройте график
# Назовите график
# Сделайте именование оси x и оси y
# Сделайте выводы

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(x= df['Price_euros'], y= df['Cpu_Company'])
plt.xlabel('Стоимость')
plt.ylabel('Производитель CPU');

# %% [markdown]
# 4.2 Изучите взаимосвязь стоимости ноутбука и типа носителя памяти

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(x= df['Price_euros'], y= df['Memory_Type'])
plt.xlabel('Стоимость')
plt.ylabel('Тип Памяти');

# %% [markdown]
# 4.3 Изучите взаимосвязь стоимости ноутбука и кол-ва оперативной памяти

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(x= df['Price_euros'], y= df['Ram'])
plt.xlabel('Стоимость')
plt.ylabel('Тип Памяти');

# %% [markdown]
# 4.4 Изучите взаимосвязь стоимости ноутбука и компании производителя

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(x= df['Price_euros'], y= df['Company'])
plt.xlabel('Стоимость')
plt.ylabel('Тип Памяти');

# %%
list_p = ['Inches', 'Memory_Amount', 'Weight', 'Price_euros']
new_df = df[list_p]

corr_matrix = new_df.corr()
corr_matrix[np.abs(corr_matrix)<=0.2] = 0
corr_matrix
# Out:
#                  Inches  Memory_Amount    Weight  Price_euros
# Inches         1.000000       0.269718  0.827631      0.00000
# Memory_Amount  0.269718       1.000000  0.000000      0.00000
# Weight         0.827631       0.000000  1.000000      0.21037
# Price_euros    0.000000       0.000000  0.210370      1.00000

# %%
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot: >
